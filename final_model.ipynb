# %%
import os
import sys
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
from mrcnn import utils
from mrcnn import visualize
from mrcnn.model import log
# Out:
# C:\Users\shrey\Crater-Detection-on-Lunar-Surface\mrcnn\model.py:2362: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if os.name is 'nt':

# %%
from model import lunar_crater

# %%
config = lunar_crater.CraterConfig()

# %%
dataset = lunar_crater.CraterDataset()

# %%
dataset.load_crater("data\\train")

# %%
dataset.prepare()

# %%
len(dataset.image_ids)
# Out:
# 88

# %%
print("Image Count: {}".format(len(dataset.image_ids)))
print("Class Count: {}".format(dataset.num_classes))
# Out:
# Image Count: 88
# Class Count: 2

# %%
for i, info in enumerate(dataset.class_info):
    print("{:3}. {:50}".format(i, info['name']))
# Out:
#   0. BG
#   1. crater

# %%
image_id = 'data/val/mars_crater (91).jpg'
image = dataset.load_image(image_id)

# %%
mask, class_ids = dataset.load_mask(0)

# %%
for i in range(len(dataset.image_ids)):
    print(i, dataset.image_info[i]['id'])
# Out:
# 0 mars_crater (0).jpg
# 1 mars_crater (1).png
# 2 mars_crater (2).jpg
# 3 mars_crater (2).png
# 4 mars_crater (3).jpg
# 5 mars_crater (4).jpg
# 6 mars_crater (5).jpg
# 7 mars_crater (6).jpg
# 8 mars_crater (7).jpg
# 9 mars_crater (8).jpg
# 10 mars_crater (9).jpg
# 11 mars_crater (10).jpg
# 12 mars_crater (11).jpg
# 13 mars_crater (12).jpg
# 14 mars_crater (13).jpg
# 15 mars_crater (14).jpg
# 16 mars_crater (15).jpg
# 17 mars_crater (16).jpg
# 18 mars_crater (17).jpg
# 19 mars_crater (18).jpg
# 20 mars_crater (19).jpg
# 21 mars_crater (20).jpg
# 22 mars_crater (21).jpg
# 23 mars_crater (22).jpg
# 24 mars_crater (23).jpg
# 25 mars_crater (24).jpg
# 26 mars_crater (25).jpg
# 27 mars_crater (26).jpg
# 28 mars_crater (27).jpg
# 29 mars_crater (28).jpg
# 30 mars_crater (29).jpg
# 31 mars_crater (30).jpg
# 32 mars_crater (31).jpg
# 33 mars_crater (32).jpg
# 34 mars_crater (33).jpg
# 35 mars_crater (34).jpg
# 36 mars_crater (35).jpg
# 37 mars_crater (36).jpg
# 38 mars_crater (37).jpg
# 39 mars_crater (38).jpg
# 40 mars_crater (39).jpg
# 41 mars_crater (40).jpg
# 42 mars_crater (41).jpg
# 43 mars_crater (42).jpg
# 44 mars_crater (43).jpg
# 45 mars_crater (44).jpg
# 46 mars_crater (45).jpg
# 47 mars_crater (46).jpg
# 48 mars_crater (47).jpg
# 49 mars_crater (48).jpg
# 50 mars_crater (50).jpg
# 51 mars_crater (51).jpg
# 52 mars_crater (52).jpg
# 53 mars_crater (53).jpg
# 54 mars_crater (54).jpg
# 55 mars_crater (55).jpg
# 56 mars_crater (56).jpg
# 57 mars_crater (57).jpg
# 58 mars_crater (58).jpg
# 59 mars_crater (59).jpg
# 60 mars_crater (60).jpg
# 61 mars_crater (61).jpg
# 62 mars_crater (62).jpg
# 63 mars_crater (63).jpg
# 64 mars_crater (64).jpg
# 65 mars_crater (65).jpg
# 66 mars_crater (66).jpg
# 67 mars_crater (67).jpg
# 68 mars_crater (68).jpg
# 69 mars_crater (69).jpg
# 70 mars_crater (70).jpg
# 71 mars_crater (71).jpg
# 72 mars_crater (73).jpg
# 73 mars_crater (74).jpg
# 74 mars_crater (75).jpg
# 75 mars_crater (76).jpg
# 76 mars_crater (78).jpg
# 77 mars_crater (80).jpg
# 78 mars_crater (81).jpg
# 79 mars_crater (82).jpg
# 80 mars_crater (83).jpg
# 81 mars_crater (84).jpg
# 82 mars_crater (85).jpg
# 83 mars_crater (86).jpg
# 84 mars_crater (87).jpg
# 85 mars_crater (88).jpg
# 86 mars_crater (89).jpg
# 87 mars_crater (90).jpg

# %%
mask, class_ids = dataset.load_mask(0)

# %%
bbox = utils.extract_bboxes(mask)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off')
plt.show
plt.show()

# %%
import cv2

# %%
image = cv2.resize(image, (mask.shape[1], mask.shape[0]))

# %%
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)
# Out:
# image                    shape: (788, 1400, 3)        min:    0.00000  max:  255.00000  uint8
# mask                     shape: (788, 1400, 88)       min:    0.00000  max:    1.00000  bool
# class_ids                shape: (88,)                 min:    1.00000  max:    1.00000  int32
# bbox                     shape: (88, 4)               min:   11.00000  max: 1397.00000  int32

# %%
print("Loaded Image Path:", dataset.image_info[0]['path'])
# Out:
# Loaded Image Path: data\train\mars_crater (0).jpg
